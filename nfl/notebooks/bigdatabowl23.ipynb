# %%
# Main
import sys
sys.path.append("..")
from reuse.bigdatabowl import *

# Visualization
import imageio
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.animation as animation
from IPython.display import display, HTML
from matplotlib.patches import Ellipse
from IPython.display import Image
from matplotlib.animation import FuncAnimation

# %%
# Turn off max columns for pandas DataFrame
pd.set_option('display.max_columns', None)

# %%
plays = pd.read_csv('../data/nfl-big-data-bowl-2023/plays.csv')

# %%
df = pd.read_csv('../data/nfl-big-data-bowl-2023/week3.csv')

# %%
df = df.merge(plays, on=['gameId', 'playId'])

# %%
# Usage
gameId = 2021092300
playId = 78
play_animation = PlayAnimation(df, gameId, playId)
play_animation.plot_play()
# Out:
# MovieWriter imagemagick unavailable; using Pillow instead.
