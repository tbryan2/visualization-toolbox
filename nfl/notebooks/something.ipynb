# %%
# Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
from adjustText import adjust_text

import nfl_data_py as nfl

# %%
years = range(2021, 2023)

# %%
nfl.import_combine_data(years)
# Out:
#       season  draft_year            draft_team  draft_round  draft_ovr  \
# 6892    2021         NaN                  None          NaN        NaN
# 6893    2021      2021.0    New Orleans Saints          3.0       76.0
# 6894    2021         NaN                  None          NaN        NaN
# 6895    2021         NaN                  None          NaN        NaN
# 6896    2021         NaN                  None          NaN        NaN
# ...      ...         ...                   ...          ...        ...
# 7675    2022      2022.0     Green Bay Packers          1.0       28.0
# 7676    2022         NaN                  None          NaN        NaN
# 7677    2022      2022.0      Cleveland Browns          4.0      124.0
# 7678    2022      2022.0   San Francisco 49ers          6.0      187.0
# 7679    2022      2022.0  New England Patriots          4.0      137.0
#
#         pfr_id               cfb_id      player_name pos            school  \
# ...
